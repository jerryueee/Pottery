# %%
import importlib
import visualize

importlib.reload(visualize)

path = r"D:\code\computer_version_hw\Pottery\data\test\1\BA_42_2-n003-t1649437795.vox"

path1 = r"D:\code\computer_version_hw\Pottery\data\test\1\TU_110_3-n016-t1649440209.vox"

vox = visualize.__read_vox__(path)

vox1 = visualize.__read_vox__(path1)

visualize.plot_frag(vox1, "result.png")

# visualize.plot_join(vox, vox1, "result.png")
