# %%
import visualize
import numpy as np

import importlib
importlib.reload(visualize)

path = r"D:\code\computer_version_hw\Pottery\data\test\8\PO_023-n011-t1649439961.vox"

vox = visualize.__read_vox__(path)
vox_frag = visualize.__read_vox_frag__(path,4)

np.set_printoptions(threshold=np.inf)
print(vox.shape)
print(vox_frag.shape)

import sys

with open("output.txt",'w') as f:
    print(vox, file=f)
# Out:
# (64, 64, 64)
# (64, 64, 64)
